# %% [markdown]
#  DSC-037 step 3: Assessment & Verfication
# ---
# DSC-037: Cable reflection systematics for EoR science
#
# ### Authors:
# SHAO EoR Group and Teal Team
#
# ### Documentation on confluence:
#
# Summary: This notebook is a first implementation of DSC-037 to plot amplitude and phase of calibration solutions to assess temporal and spectral smoothnessss.
#
# DSC description page: https://confluence.skatelescope.org/x/0rs6F
# Chronological walkthrough: https://confluence.skatelescope.org/x/osw6F
# Implementation: https://confluence.skatelescope.org/x/n8LMF
# GitHub repo: https://github.com/uksrc-developers/dsc-037-eor
#
#
# Ticket: TEAL-1128 https://jira.skatelescope.org/browse/TEAL-1128
#
# **Dependencies:**  `numpy`, `astropy`
#
# Last updated: 2025-10-16

# %%
# %matplotlib inline

from plot_calibration_solutions import run_calibration_plotting

# %% [markdown]
# # Example: Plotting Calibration Solutions
#
# This notebook uses `plot_calibration_solutions.py` to plot calibration solutions.
# Parameters can be set in `config.yaml` or passed directly as function arguments.
#
# The calibration solution file hyp_soln_1184702048_ssins_30l_src8k_300it.fits used in this code
# was provided by Hyperdrive, courtesy of Dev Null.

# %%
# --- Execute using config.yaml and notebook parameters ---
# Common parameters from config.yaml: input_file, i_timeblock, figsize, etc.
# To customize, edit config.yaml for common params, or modify parameters below to override

# Option 1: Use defaults from config.yaml:
# results = run_calibration_plotting('config.yaml')

# Option 2: Override specific parameters:
# results = run_calibration_plotting(
#     config_file='config.yaml',
#     input_file="hyp_soln_1184702048_ssins_30l_src8k_300it.fits",
#     i_timeblock=0,
#     output_amp="./Amplitude Solutions vs Frequency.png",
#     output_phase="./Phase Solutions vs Frequency.png",
#     show=True  # Display plots instead of saving
# )

# For now, using defaults from config.yaml:
results = run_calibration_plotting('config.yaml')
# Out:
# [INFO] Loading calibration solutions from: hyp_soln_1184702048_ssins_30l_src8k_300it.fits
# [INFO] Using time block: 0
# [INFO] Plotting amplitude solutions...
# [INFO] Plotting phase solutions...
# [INFO] Displayed 2 plots. Close all windows to continue.

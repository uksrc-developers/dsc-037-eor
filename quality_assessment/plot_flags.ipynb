# %% [markdown]
# # DSC-037 Step 3: Flag Occupancy Assessment
# ---
# DSC-037: Cable reflection systematics for EoR science
#
# ### Authors:
# Flag occupancy plot codes originally written by Dev Null, modified and integrated
# by SHAO EOR Group and Teal Team
#
# ### Documentation on Confluence:
#
# Summary: This notebook provides a reference implementation of DSC-037 step 3 to
# visualise flag occupancy (fraction of flagged visibilities) for individual
# baselines, helping assess temporal and spectral data quality.
#
# DSC description page: https://confluence.skatelescope.org/x/0rs6F
# Chronological walkthrough: https://confluence.skatelescope.org/x/osw6F
# Implementation: https://confluence.skatelescope.org/x/n8LMF
# GitHub repo: https://github.com/uksrc-developers/dsc-037-eor
#
# Ticket: TEAL-1128 https://jira.skatelescope.org/browse/TEAL-1128
#
# This notebook plots flag occupancy vs time/frequency for datasets in either:
# 1. LOFAR Measurement Set (MS) format (using casacore)
# 2. UVFITS or other formats supported by pyuvdata
#
# **Dependencies:** `casacore-tools`, `python-casacore`, `pyuvdata`, `numpy`, `matplotlib`, `astropy`, `pyyaml`
#
# Last updated: 2025-11-08

# %%
# %matplotlib inline

from plot_flags import run_flag_plotting

# %% [markdown]
# # Example: Flag Occupancy Visualisation
# The input UVFITS data file `hyp_1184702048_ionosub_ssins_30l_src8k_300it_8s_80kHz_i1000.uvfits`
# used here was provided by Hyperdrive, courtesy of Dev Null.
#
# To customise the plots, edit `config.yaml` (for shared parameters) or override
# arguments in the call below.

# %%
# --- Execute using config.yaml and notebook parameters ---
# Common parameters from config.yaml: input_file, format, outdir, show
# To override, provide arguments to run_flag_plotting as shown below.

# Example override (uncomment and edit as needed):
# plot_path = run_flag_plotting(
#     input_file="your_file.uvfits",
#     format_type="uvfits",
#     outdir="./flag_plots",
#     cmap="plasma"
# )

# Use defaults from config.yaml and notebook:
run_flag_plotting('config.yaml')
# Out:
# [INFO] Plotting MS flag occupancy (cmap=viridis)
# Successful readonly open of default-locked table L253456_SAP000_002_time1.flagged.5ch8s.dical.MS: 24 columns, 840150 rows
# Successful readonly open of default-locked table L253456_SAP000_002_time1.flagged.5ch8s.dical.MS::SPECTRAL_WINDOW: 14 columns, 1 rows
# max_occupancy=0.24799143010176755 full_occupancy_value varies per-time

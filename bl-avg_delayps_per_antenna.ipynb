# %% [markdown]
# # DSC-037 step 4: Compute delay power spectra

# %% [markdown]
# ---
#
# **DSC-037**: Cable reflection systematics for EoR science
#
# **Author:** Adélie Gorce and Teal team
#
# **Documentation on confluence:**
# - DSC description page: https://confluence.skatelescope.org/x/0rs6F
# - Chronological walkthrough: https://confluence.skatelescope.org/x/osw6F
# - Implementation: https://confluence.skatelescope.org/x/n8LMF
# - GitHub repo: https://github.com/uksrc-developers/dsc-037-eor
#
# **Summary:**  This notebook is a first implementation of the step 4 of DSC-037 (see chronological walkthrough above) to calculate delay power spectra for individual baselines and then cylindrically averaged power spectra for a user-specified set of frequencies, times, and polarisations.
# In this notebook, we
# - Load the visibilities
# - Compute a delay power spectrum for a single antenna (and all associated baselines) using the `pyuvdata` and `hera_pspec` packages
#
#
# **Ticket:** TEAL-1129 https://jira.skatelescope.org/browse/TEAL-1129
#
#
# **Data:**
# We use the MWA dataset available on Rucio (https://confluence.skatelescope.org/x/tnTGEg) as a proxy for DV AA2 data. The dataset has the following structure:
# - Integration time: 8s
# - Total time: 112s
# - Bandwidth: 31 MHz
# - Central frequency: 182 MHz
# - Number of channels: 384
# - Channel width: 80 kHz
# - Processing applied: DI-calibration and sky model subtraction
# - Calibration solutions available
# - Size: 1.9 GB

# %%
# import required packages
import numpy as np
from astropy.time import Time
from tqdm import tqdm
import os
import matplotlib.pyplot as plt
from matplotlib import colors, colormaps

# %%
import hera_pspec as hp
import pyuvdata
from utils import load_config

# %%
print(*(f"{pkg} version: {__import__(pkg).__version__}" for pkg in ['numpy', 'astropy', 'matplotlib', 'pyuvdata', 'hera_pspec']), sep='\n')
# Out:
# numpy version: 2.2.4
# astropy version: 7.0.1
# matplotlib version: 3.10.1
# pyuvdata version: 3.2.1
# hera_pspec version: 0.4.3.dev89+ge63e2a1.d20250801

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Load configuration

# %% [markdown]
# The antenna(s), time range, frequency range, polarization to analyse are specified in a configuration file.
# The configuration file also specifies the datafile to consider and its location.
# The information is then loaded with the `load_config` method.

# %%
dic = load_config('init.yaml', verbose=True)
# Out:
# No antennas specified; using all antennas in data (121).
# No times specified; using all timestamps in data (14).
# Loaded MWA dataset with required configuration.
# Selected frequency range: [175.075, 183.075] MHz, corresponding to average redshift of 6.9.
# Selected polarization: -5 (xx)

# %% [markdown]
# ## Inspect dataset

# %% [markdown]
# Load the metadata to inspect global dataset

# %%
uvd_meta = pyuvdata.UVData()
uvd_meta.read_uvfits(os.path.join(dic['datafolder'], dic['datafile']), read_data=False)

# %%
print(f'Number of baselines: {uvd_meta.Nbls}')
print(f'Number of times: {uvd_meta.Ntimes}')
print(f'Number of frequencies: {uvd_meta.Nfreqs}')
print(f'Number of polarizations: {uvd_meta.Npols} ({uvd_meta.polarization_array})')
# Out:
# Number of baselines: 7381
# Number of times: 14
# Number of frequencies: 384
# Number of polarizations: 4 ([-5 -6 -7 -8])

# %%
# for now, no beam
uvb = None
# MWA beam model (from Dev)
# beamfile = 'mwa_full_embedded_element_pattern.h5'
# # read in delays to adjust zero phase of beam
# from astropy.io import fits
# metafits_file = datafile.split('_')[1]+'.metafits'
# with fits.open(os.path.join(datafolder, metafits_file)) as hdul:
#     data = hdul['TILEDATA'].data
# delays = np.array([data[0]['Delays'], data[0]['Delays']])
# # create UVBeam object and read in MWA beam
# uvb = pyuvdata.UVBeam()
# uvb.read_mwa_beam(os.path.join(datafolder, beamfile), delays=delays)

# %% [markdown]
# ## Baseline-averaged delay-PS grouped by antenna

# %% [markdown]
# Build delay power spectra, but only for baselines including a specific antenna.

# %%
# find indices to select frequency range (use in hp.pspec)
spw_ranges = [tuple([list(uvd_meta.freq_array).index(dic['freq_range'][i]*1e6) for i in (0, 1)])  ]

# %%
# loop over antennas to build delay power spectra
data_time_avg = np.zeros((len(dic['antenna_nums']), np.diff(spw_ranges[0])[0]//2-1))
data_per_antenna = np.zeros((len(dic['antenna_nums']), dic['Ntimes'], np.diff(spw_ranges[0])[0]//2-1))
for u, antenna_num in enumerate(tqdm(dic['antenna_nums'])):
    # create UVData object and read in data
    uvd = pyuvdata.UVData()
    uvd.read(
        os.path.join(dic['datafolder'], dic['datafile']),
        polarizations=[dic['pol']],
        time_range=dic['time_range'],
        # freq_chans=np.arange(spw_ranges[0][0], spw_ranges[0][1]),
        keep_all_metadata=False,
        read_data=True,
    )
    # select data for a single antenna
    uvd.select(ant_str=f'{antenna_num}')
    # average over all the baselines including said antenna
    uvd.compress_by_redundancy(tol=100000., use_grid_alg=True)
    # Create a new PSpecData object which will be used to compute the delay PS
    ds = hp.PSpecData(dsets=[uvd, uvd], wgts=[None, None], beam=uvb)
    # in the baseline-averaged dataset, there is only one baseline left (the first one)
    bl = uvd.baseline_to_antnums(uvd.baseline_array[0])
    # build time-averaged delay ps from pairing the baseline with itself
    uvp = ds.pspec(
        [bl], [bl], # select the baselines to cross (here, with itself)
        dsets=(0, 1), # select which datasets to use within ds
        pols=[(dic['pol'], dic['pol'])],  # select the polarisation channels to cross
        spw_ranges=spw_ranges,  # select a smaller bandwidth
        verbose=False
    )
    # save time array for per-antenna figure
    if u == 0:
        time_array = Time(uvp.time_avg_array, format='jd')
    # fold spectrum over the delay axis
    hp.grouping.fold_spectra(uvp)
    # save delay power spectrum per antenna, as a function of time and delay
    data_per_antenna[u] = np.abs(uvp.data_array[0][:, -uvp.get_dlys(0).size:, 0])
    # take time average of the data
    uvp.average_spectra(time_avg=True, inplace=True)
    # save time-averaged delay power spectrum per antenna
    data_time_avg[u] = np.abs(uvp.data_array[0][0, -uvp.get_dlys(0).size:, 0])
# define time array for per-antenna figure
t_ref = Time(uvp.time_avg_array.min(), format='jd')
time_array = (time_array - t_ref).to('s').value
# Out:
#   0%|          | 0/121 [00:00<?, ?it/s]Casting complex values to real discards the imaginary part
#   1%|          | 1/121 [00:03<07:43,  3.86s/it]Casting complex values to real discards the imaginary part
#   2%|▏         | 2/121 [00:06<06:12,  3.13s/it]Casting complex values to real discards the imaginary part
#   2%|▏         | 3/121 [00:08<05:21,  2.72s/it]Casting complex values to real discards the imaginary part
#   3%|▎         | 4/121 [00:11<05:21,  2.75s/it]Casting complex values to real discards the imaginary part
#   4%|▍         | 5/121 [00:13<04:59,  2.58s/it]Casting complex values to real discards the imaginary part
#   5%|▍         | 6/121 [00:15<04:41,  2.44s/it]Casting complex values to real discards the imaginary part
#   6%|▌         | 7/121 [00:17<04:20,  2.28s/it]Casting complex values to real discards the imaginary part
#   7%|▋         | 8/121 [00:19<04:04,  2.16s/it]Casting complex values to real discards the imaginary part
#   7%|▋         | 9/121 [00:21<03:57,  2.12s/it]Casting complex values to real discards the imaginary part
#   8%|▊         | 10/121 [00:23<03:52,  2.09s/it]Casting complex values to real discards the imaginary part
#   9%|▉         | 11/121 [00:25<03:43,  2.03s/it]Casting complex values to real discards the imaginary part
#  10%|▉         | 12/121 [00:27<03:38,  2.01s/it]Casting complex values to real discards the imaginary part
#  11%|█         | 13/121 [00:30<03:46,  2.09s/it]Casting complex values to real discards the imaginary part
#  12%|█▏        | 14/121 [00:32<03:46,  2.11s/it]Casting complex values to real discards the imaginary part
#  12%|█▏        | 15/121 [00:34<03:38,  2.06s/it]Casting complex values to real discards the imaginary part
#  13%|█▎        | 16/121 [00:36<03:37,  2.07s/it]Casting complex values to real discards the imaginary part
#  14%|█▍        | 17/121 [00:38<03:29,  2.01s/it]Casting complex values to real discards the imaginary part
#  15%|█▍        | 18/121 [00:40<03:34,  2.08s/it]Casting complex values to real discards the imaginary part
#  16%|█▌        | 19/121 [00:42<03:25,  2.02s/it]Casting complex values to real discards the imaginary part
#  17%|█▋        | 20/121 [00:44<03:19,  1.98s/it]Casting complex values to real discards the imaginary part
#  17%|█▋        | 21/121 [00:45<03:14,  1.94s/it]Casting complex values to real discards the imaginary part
#  18%|█▊        | 22/121 [00:47<03:14,  1.97s/it]Casting complex values to real discards the imaginary part
#  19%|█▉        | 23/121 [00:50<03:17,  2.01s/it]Casting complex values to real discards the imaginary part
#  20%|█▉        | 24/121 [00:52<03:13,  1.99s/it]Casting complex values to real discards the imaginary part
#  21%|██        | 25/121 [00:54<03:11,  1.99s/it]Casting complex values to real discards the imaginary part
#  21%|██▏       | 26/121 [00:55<03:07,  1.97s/it]Casting complex values to real discards the imaginary part
#  22%|██▏       | 27/121 [00:57<03:03,  1.95s/it]Casting complex values to real discards the imaginary part
#  23%|██▎       | 28/121 [00:59<03:05,  2.00s/it]Casting complex values to real discards the imaginary part
#  24%|██▍       | 29/121 [01:01<03:04,  2.00s/it]Casting complex values to real discards the imaginary part
#  25%|██▍       | 30/121 [01:03<03:00,  1.99s/it]Casting complex values to real discards the imaginary part
#  26%|██▌       | 31/121 [01:05<02:59,  1.99s/it]Casting complex values to real discards the imaginary part
#  26%|██▋       | 32/121 [01:07<02:58,  2.00s/it]Casting complex values to real discards the imaginary part
#  27%|██▋       | 33/121 [01:09<02:56,  2.01s/it]Casting complex values to real discards the imaginary part
#  28%|██▊       | 34/121 [01:11<02:53,  1.99s/it]Casting complex values to real discards the imaginary part
#  29%|██▉       | 35/121 [01:14<02:53,  2.01s/it]Casting complex values to real discards the imaginary part
#  30%|██▉       | 36/121 [01:15<02:50,  2.00s/it]Casting complex values to real discards the imaginary part
#  31%|███       | 37/121 [01:17<02:47,  2.00s/it]Casting complex values to real discards the imaginary part
#  31%|███▏      | 38/121 [01:19<02:45,  1.99s/it]Casting complex values to real discards the imaginary part
#  32%|███▏      | 39/121 [01:22<02:45,  2.01s/it]Casting complex values to real discards the imaginary part
#  33%|███▎      | 40/121 [01:23<02:41,  1.99s/it]Casting complex values to real discards the imaginary part
#  34%|███▍      | 41/121 [01:26<02:42,  2.03s/it]Casting complex values to real discards the imaginary part
#  35%|███▍      | 42/121 [01:27<02:36,  1.98s/it]Casting complex values to real discards the imaginary part
#  36%|███▌      | 43/121 [01:29<02:31,  1.94s/it]Casting complex values to real discards the imaginary part
#  36%|███▋      | 44/121 [01:31<02:26,  1.90s/it]Casting complex values to real discards the imaginary part
#  37%|███▋      | 45/121 [01:33<02:23,  1.89s/it]Casting complex values to real discards the imaginary part
#  38%|███▊      | 46/121 [01:35<02:22,  1.90s/it]Casting complex values to real discards the imaginary part
#  39%|███▉      | 47/121 [01:37<02:25,  1.97s/it]Casting complex values to real discards the imaginary part
#  40%|███▉      | 48/121 [01:39<02:21,  1.94s/it]Casting complex values to real discards the imaginary part
#  40%|████      | 49/121 [01:41<02:20,  1.96s/it]Casting complex values to real discards the imaginary part
#  41%|████▏     | 50/121 [01:43<02:17,  1.94s/it]Casting complex values to real discards the imaginary part
#  42%|████▏     | 51/121 [01:45<02:17,  1.97s/it]Casting complex values to real discards the imaginary part
#  43%|████▎     | 52/121 [01:47<02:15,  1.97s/it]Casting complex values to real discards the imaginary part
#  44%|████▍     | 53/121 [01:49<02:14,  1.97s/it]Casting complex values to real discards the imaginary part
#  45%|████▍     | 54/121 [01:51<02:10,  1.95s/it]Casting complex values to real discards the imaginary part
#  45%|████▌     | 55/121 [01:53<02:07,  1.93s/it]Casting complex values to real discards the imaginary part
#  46%|████▋     | 56/121 [01:54<02:03,  1.91s/it]Casting complex values to real discards the imaginary part
#  47%|████▋     | 57/121 [01:56<02:03,  1.93s/it]Casting complex values to real discards the imaginary part
#  48%|████▊     | 58/121 [01:58<02:00,  1.92s/it]Casting complex values to real discards the imaginary part
#  49%|████▉     | 59/121 [02:00<01:58,  1.91s/it]Casting complex values to real discards the imaginary part
#  50%|████▉     | 60/121 [02:02<01:57,  1.92s/it]Casting complex values to real discards the imaginary part
#  50%|█████     | 61/121 [02:04<01:55,  1.93s/it]Casting complex values to real discards the imaginary part
#  51%|█████     | 62/121 [02:06<01:55,  1.96s/it]Casting complex values to real discards the imaginary part
#  52%|█████▏    | 63/121 [02:08<01:52,  1.95s/it]Casting complex values to real discards the imaginary part
#  53%|█████▎    | 64/121 [02:10<01:50,  1.94s/it]Casting complex values to real discards the imaginary part
#  54%|█████▎    | 65/121 [02:12<01:47,  1.93s/it]Casting complex values to real discards the imaginary part
#  55%|█████▍    | 66/121 [02:14<01:44,  1.91s/it]Casting complex values to real discards the imaginary part
#  55%|█████▌    | 67/121 [02:16<01:42,  1.90s/it]Casting complex values to real discards the imaginary part
#  56%|█████▌    | 68/121 [02:18<01:42,  1.92s/it]divide by zero encountered in divide
#  57%|█████▋    | 69/121 [02:19<01:39,  1.92s/it]Casting complex values to real discards the imaginary part
#  58%|█████▊    | 70/121 [02:21<01:37,  1.91s/it]Casting complex values to real discards the imaginary part
#  59%|█████▊    | 71/121 [02:23<01:34,  1.90s/it]Casting complex values to real discards the imaginary part
#  60%|█████▉    | 72/121 [02:25<01:34,  1.92s/it]Casting complex values to real discards the imaginary part
#  60%|██████    | 73/121 [02:27<01:32,  1.92s/it]Casting complex values to real discards the imaginary part
#  61%|██████    | 74/121 [02:29<01:29,  1.91s/it]Casting complex values to real discards the imaginary part
#  62%|██████▏   | 75/121 [02:31<01:27,  1.90s/it]Casting complex values to real discards the imaginary part
#  63%|██████▎   | 76/121 [02:33<01:27,  1.94s/it]Casting complex values to real discards the imaginary part
#  64%|██████▎   | 77/121 [02:35<01:26,  1.97s/it]Casting complex values to real discards the imaginary part
#  64%|██████▍   | 78/121 [02:37<01:23,  1.94s/it]Casting complex values to real discards the imaginary part
#  65%|██████▌   | 79/121 [02:39<01:22,  1.98s/it]Casting complex values to real discards the imaginary part
#  66%|██████▌   | 80/121 [02:41<01:22,  2.00s/it]Casting complex values to real discards the imaginary part
#  67%|██████▋   | 81/121 [02:43<01:22,  2.06s/it]Casting complex values to real discards the imaginary part
#  68%|██████▊   | 82/121 [02:46<01:31,  2.34s/it]Casting complex values to real discards the imaginary part
#  69%|██████▊   | 83/121 [02:48<01:26,  2.28s/it]Casting complex values to real discards the imaginary part
#  69%|██████▉   | 84/121 [02:51<01:26,  2.35s/it]Casting complex values to real discards the imaginary part
#  70%|███████   | 85/121 [02:53<01:21,  2.26s/it]Casting complex values to real discards the imaginary part
#  71%|███████   | 86/121 [02:55<01:16,  2.18s/it]Casting complex values to real discards the imaginary part
#  72%|███████▏  | 87/121 [02:57<01:11,  2.12s/it]Casting complex values to real discards the imaginary part
#  73%|███████▎  | 88/121 [02:59<01:07,  2.05s/it]Casting complex values to real discards the imaginary part
#  74%|███████▎  | 89/121 [03:01<01:04,  2.02s/it]Casting complex values to real discards the imaginary part
#  74%|███████▍  | 90/121 [03:03<01:02,  2.02s/it]Casting complex values to real discards the imaginary part
#  75%|███████▌  | 91/121 [03:05<01:00,  2.03s/it]Casting complex values to real discards the imaginary part
#  76%|███████▌  | 92/121 [03:07<00:57,  2.00s/it]Casting complex values to real discards the imaginary part
#  77%|███████▋  | 93/121 [03:09<00:55,  1.97s/it]Casting complex values to real discards the imaginary part
#  78%|███████▊  | 94/121 [03:11<00:53,  2.00s/it]Casting complex values to real discards the imaginary part
#  79%|███████▊  | 95/121 [03:13<00:51,  1.98s/it]Casting complex values to real discards the imaginary part
#  79%|███████▉  | 96/121 [03:15<00:49,  1.99s/it]Casting complex values to real discards the imaginary part
#  80%|████████  | 97/121 [03:16<00:47,  1.97s/it]Casting complex values to real discards the imaginary part
#  81%|████████  | 98/121 [03:19<00:45,  2.00s/it]Casting complex values to real discards the imaginary part
#  82%|████████▏ | 99/121 [03:20<00:43,  1.98s/it]Casting complex values to real discards the imaginary part
#  83%|████████▎ | 100/121 [03:22<00:41,  1.96s/it]Casting complex values to real discards the imaginary part
#  83%|████████▎ | 101/121 [03:24<00:39,  1.97s/it]Casting complex values to real discards the imaginary part
#  84%|████████▍ | 102/121 [03:27<00:40,  2.11s/it]Casting complex values to real discards the imaginary part
#  85%|████████▌ | 103/121 [03:29<00:37,  2.07s/it]Casting complex values to real discards the imaginary part
#  86%|████████▌ | 104/121 [03:31<00:34,  2.05s/it]Casting complex values to real discards the imaginary part
#  87%|████████▋ | 105/121 [03:33<00:33,  2.12s/it]Casting complex values to real discards the imaginary part
#  88%|████████▊ | 106/121 [03:35<00:31,  2.10s/it]Casting complex values to real discards the imaginary part
#  88%|████████▊ | 107/121 [03:37<00:29,  2.08s/it]Casting complex values to real discards the imaginary part
#  89%|████████▉ | 108/121 [03:39<00:27,  2.09s/it]Casting complex values to real discards the imaginary part
#  90%|█████████ | 109/121 [03:42<00:26,  2.22s/it]Casting complex values to real discards the imaginary part
#  91%|█████████ | 110/121 [03:44<00:23,  2.13s/it]Casting complex values to real discards the imaginary part
#  92%|█████████▏| 111/121 [03:46<00:20,  2.08s/it]Casting complex values to real discards the imaginary part
#  93%|█████████▎| 112/121 [03:48<00:18,  2.04s/it]Casting complex values to real discards the imaginary part
#  93%|█████████▎| 113/121 [03:50<00:16,  2.03s/it]Casting complex values to real discards the imaginary part
#  94%|█████████▍| 114/121 [03:52<00:14,  2.11s/it]Casting complex values to real discards the imaginary part
#  95%|█████████▌| 115/121 [03:54<00:13,  2.20s/it]Casting complex values to real discards the imaginary part
#  96%|█████████▌| 116/121 [03:56<00:10,  2.12s/it]Casting complex values to real discards the imaginary part
#  97%|█████████▋| 117/121 [03:58<00:08,  2.11s/it]Casting complex values to real discards the imaginary part
#  98%|█████████▊| 118/121 [04:00<00:06,  2.08s/it]Casting complex values to real discards the imaginary part
#  98%|█████████▊| 119/121 [04:02<00:04,  2.05s/it]Casting complex values to real discards the imaginary part
#  99%|█████████▉| 120/121 [04:04<00:02,  2.00s/it]Casting complex values to real discards the imaginary part
# 100%|██████████| 121/121 [04:06<00:00,  2.04s/it]

# %% [markdown]
# Gather the results in a figure presenting the time-averaged delay PS per antenna ($x$ axis) to identify which antennas are the most impacted by cable reflections

# %%
vmin = np.percentile(np.abs(data_time_avg), 2)
vmax = np.percentile(np.abs(data_time_avg), 98)

fig, ax = plt.subplots(1, 1, figsize=(15, 5))
im = ax.pcolormesh(
    dic['antenna_nums'],
    uvp.get_dlys(0)*1e6,
	np.abs(data_time_avg).T,
	cmap='Purples',
    norm=colors.Normalize(vmin=vmin, vmax=vmax),
)
cbar = fig.colorbar(im, ax=ax, label=r'Power [Jy$^2$]')
ax.set_ylabel(r'Delay [$\mu$s]')
ax.set_xlabel('Antenna number')
# Out:
# Text(0.5, 0, 'Antenna number')

# %% [markdown]
# Gather the results in a figure showing the delay power spectrum as a function of time for each antenna, in order to identify which antenna is most impacted by cable reflections

# %%
ncol = 10
nrow = np.ceil(len(dic['antenna_nums'])/ncol).astype(int)

vmin = np.percentile(np.abs(data_per_antenna), 2)
vmax = np.percentile(np.abs(data_per_antenna), 98)

fig, axes = plt.subplots(nrow, ncol, figsize=(20, 2*nrow), sharex=True, sharey=True)
for i, antenna_num in enumerate(dic['antenna_nums']):
    ax = axes.flatten()[i]
    im = ax.pcolormesh(
        time_array,
        uvp.get_dlys(0)*1e6,
        np.abs(data_per_antenna[i]).T,
        cmap='Purples',
        norm=colors.Normalize(vmin=vmin, vmax=vmax),
    )
    ax.set_title(f'A{antenna_num}')
    if i % ncol == 0:
        ax.set_ylabel(r'Delay [$\mu$s]')
    if i >= (nrow-1)*ncol:
        ax.set_xlabel('Time [s]')
for i in np.arange(ncol * nrow % len(dic['antenna_nums'])):
    axes.flatten()[-i-1].set_visible(False)
fig.tight_layout()
